# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

embed_dim = 128
hidden_dim = 256

rnn_model = nn.RNN(
    input_size=embed_dim, # 입력 임베딩 사이즈
    hidden_size=hidden_dim, # 은닉 차원수
    num_layers=1,
    batch_first=True
)
